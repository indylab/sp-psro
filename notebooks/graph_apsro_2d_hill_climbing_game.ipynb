# %%
from typing import Optional, Tuple
from grl.utils.graphing_utils import parse_run_results, graph_df_and_save_figure

graph_title = "2D Cont. Action Hill Climbing Game"
xlim: Optional[Tuple[float, float]] = (0, 1.76e7)
ylim: Optional[Tuple[float, float]] = None
use_approx_exploitability = True

# %%
# All keys are expected to be in the format "<algorithm name> <seed number>".

non_psro_runs = {
    "Self-Play 1": "/home/jblanier/git/grl/grl/data/self_play_loss_game_psro_10_moves_alpha_2.7/loss_game_psro_10_moves_alpha_2.7_sparse_11.32.05PM_Oct-20-2021mtsexx5f/loss_game_psro_10_moves_alpha_2.7_09.45.56PM_Oct-24-2021.json",
    "Self-Play 2": "/home/jblanier/git/grl/grl/data/self_play_loss_game_psro_10_moves_alpha_2.7/loss_game_psro_10_moves_alpha_2.7_sparse_11.32.40PM_Oct-20-20210n8g879d/loss_game_psro_10_moves_alpha_2.7_09.46.00PM_Oct-24-2021.json",
    "Self-Play 3": "/home/jblanier/git/grl/grl/data/self_play_loss_game_psro_10_moves_alpha_2.7/loss_game_psro_10_moves_alpha_2.7_sparse_11.33.02PM_Oct-20-20215c7wt_3e/loss_game_psro_10_moves_alpha_2.7_04.20.40PM_Jul-31-2022.json",

}

psro_runs = {
    "APSRO 1": "/home/jblanier/git/grl/grl/data/loss_game_psro_10_moves_alpha_2.7/manager_01.38.18AM_Jan-26-2022/psro_approx_stats_loss_game_psro_10_moves_alpha_2.7_01.38.18AM_Jan-26-2022.json",
    "APSRO 2": "/home/jblanier/git/grl/grl/data/loss_game_psro_10_moves_alpha_2.7/manager_01.38.50AM_Jan-26-2022/psro_approx_stats_loss_game_psro_10_moves_alpha_2.7_01.38.50AM_Jan-26-2022.json",
    "APSRO 3": "/home/jblanier/git/grl/grl/data/loss_game_psro_10_moves_alpha_2.7/manager_01.39.23AM_Jan-26-2022/psro_approx_stats_loss_game_psro_10_moves_alpha_2.7_01.39.23AM_Jan-26-2022.json",

    "PSRO 1": "/home/jblanier/git/grl/grl/data/loss_game_psro_10_moves_alpha_2.7/manager_10.54.11PM_Jan-24-2022/approx_exploitability_stats.json",
    "PSRO 2": "/home/jblanier/git/grl/grl/data/loss_game_psro_10_moves_alpha_2.7/manager_10.54.53PM_Jan-24-2022/approx_exploitability_stats.json",
    "PSRO 3": "/home/jblanier/git/grl/grl/data/loss_game_psro_10_moves_alpha_2.7/manager_10.54.53PM_Jan-24-2022/approx_exploitability_stats.json",
}

# %%
def resolve_missing_file(file_path: str) -> str:
    from grl.utils.common import assets_dir
    import os

    if not os.path.exists(file_path):
        file_relative_data_path = file_path.replace("/jb/", "/jblanier/").replace("/home/jblanier/git/grl/grl/data/", "")
        alternate_path = os.path.join(assets_dir(), "archived_data", file_relative_data_path)
        print(f"using alternate_path: {alternate_path}")
        return alternate_path
    return file_path

df = parse_run_results(non_psro_run_dict=non_psro_runs,
                       psro_run_dict=psro_runs,
                       resolve_missing_file_before_read_callback=resolve_missing_file,
                       parse_approximate_exploitability=use_approx_exploitability)
# Out:
# parsing /home/jblanier/git/grl/grl/data/self_play_loss_game_psro_10_moves_alpha_2.7/loss_game_psro_10_moves_alpha_2.7_sparse_11.32.05PM_Oct-20-2021mtsexx5f/loss_game_psro_10_moves_alpha_2.7_09.45.56PM_Oct-24-2021.json
# using alternate_path: /home/jb/git/sp-psro/grl/assets/archived_data/self_play_loss_game_psro_10_moves_alpha_2.7/loss_game_psro_10_moves_alpha_2.7_sparse_11.32.05PM_Oct-20-2021mtsexx5f/loss_game_psro_10_moves_alpha_2.7_09.45.56PM_Oct-24-2021.json
# parsing /home/jblanier/git/grl/grl/data/self_play_loss_game_psro_10_moves_alpha_2.7/loss_game_psro_10_moves_alpha_2.7_sparse_11.32.40PM_Oct-20-20210n8g879d/loss_game_psro_10_moves_alpha_2.7_09.46.00PM_Oct-24-2021.json
# using alternate_path: /home/jb/git/sp-psro/grl/assets/archived_data/self_play_loss_game_psro_10_moves_alpha_2.7/loss_game_psro_10_moves_alpha_2.7_sparse_11.32.40PM_Oct-20-20210n8g879d/loss_game_psro_10_moves_alpha_2.7_09.46.00PM_Oct-24-2021.json
# ...

# %%
graph_df_and_save_figure(
    non_psro_run_dict=non_psro_runs,
    psro_run_dict=psro_runs,
    df=df,
    title=graph_title,
    xlim=xlim,
    ylim=ylim,
    use_approx_exploitability=use_approx_exploitability)
# Out:
# /home/jb/git/sp-psro/grl/utils/graphing_utils.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df_experiment["quantized_episodes"] = _df_experiment["episodes"]
# /home/jb/git/sp-psro/grl/utils/graphing_utils.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df_experiment["quantized_episodes"] = [interval.mid for interval in pd.qcut(_df_experiment["episodes"],
# /home/jb/git/sp-psro/grl/utils/graphing_utils.py:154: SettingWithCopyWarning:
# ...
